# %% [markdown]
# # Hello, world!
#
# A minimal example notebook, here only to demonstrate the template's file-download link. Replace it with your own.

# %%
print("Hello from the LUMI AI Factory course template!")
